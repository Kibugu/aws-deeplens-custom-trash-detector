# %% [markdown]
# This notebook demonstrates how to leverage transfer learning to use your own image dataset to build and train an image classification model using MXNet and Amazon SageMaker.

# %% [markdown]
# We use, as an example, the creation of a trash classification model which, given some image, classifies it into one of three classes: compost, landfill, recycle. This is based on the [Show Before You Throw](https://www.youtube.com/watch?v=Ut1VGG6TOOw) project from an AWS DeepLens hackathon and the [Smart Recycle Arm](https://www.youtube.com/watch?v=QF0QjRjBwFs) project presented at the AWS Public Sector Summit 2019

# %% [markdown]
# ---
#
# 1. [Prerequisites](#Prerequisites)
# 1. [Download Data](#Download-data)
# 1. [Fine-tuning the Image Classification Model](#Fine-tuning-the-Image-classification-model)
# 1. [Start the Training](#Start-the-training)
# 1. [Test your Model](#Inference)
# 1. [Deploy your Model to AWS DeepLens](#Deploy)

# %% [markdown]
# ## Prequisites
#
# - Amazon Sagemaker notebook should have internet access to download images needed for testing this notebook. This is turned ON by default. To explore aoptions review this link : [Sagemaker routing options](https://aws.amazon.com/blogs/machine-learning/understanding-amazon-sagemaker-notebook-instance-networking-configurations-and-advanced-routing-options/)
# - The IAM role assigned to this notebook should have permissions to create a bucket (if it does not exist)
#   - [IAM role for Amazon Sagemaker](https://docs.aws.amazon.com/glue/latest/dg/create-an-iam-role-sagemaker-notebook.html)
#   - [S3 create bucket permissions](https://docs.aws.amazon.com/AmazonS3/latest/dev/using-with-s3-actions.html#using-with-s3-actions-related-to-buckets)

# %% [markdown]
# ### Permissions and environment variables
#
# Here we set up the linkage and authentication to AWS services. There are 2 parts to this:
#
# * The roles used to give learning and hosting access to your data. This will automatically be obtained from the role used to start the notebook
# * The Amazon sagemaker image classification docker image which need not be changed

# %%
# !pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.18.44-py3-none-any.whl (131 kB)
# Collecting botocore<1.22.0,>=1.21.44
#   Downloading botocore-1.21.44-py3-none-any.whl (7.9 MB)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.0-py3-none-any.whl (79 kB)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from botocore<1.22.0,>=1.21.44->boto3) (1.26.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from botocore<1.22.0,>=1.21.44->boto3) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.22.0,>=1.21.44->boto3) (1.15.0)
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.18.44 botocore-1.21.44 jmespath-0.10.0 s3transfer-0.5.0
# WARNING: You are using pip version 21.1.2; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\users\admin\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install botocore
# Out:
# Requirement already satisfied: botocore in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (1.21.44)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from botocore) (0.10.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from botocore) (1.26.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from botocore) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore) (1.15.0)
# WARNING: You are using pip version 21.1.2; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\users\admin\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install sagemaker
# Out:
# Collecting sagemaker
#   Downloading sagemaker-2.59.2.tar.gz (442 kB)
# Requirement already satisfied: attrs in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from sagemaker) (21.2.0)
# Requirement already satisfied: boto3>=1.16.32 in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from sagemaker) (1.18.44)
# Requirement already satisfied: google-pasta in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from sagemaker) (0.2.0)
# Requirement already satisfied: numpy>=1.9.0 in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from sagemaker) (1.19.5)
# Requirement already satisfied: protobuf>=3.1 in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from sagemaker) (3.15.8)
# Collecting protobuf3-to-dict>=0.1.5
#   Downloading protobuf3-to-dict-0.1.5.tar.gz (3.5 kB)
# Collecting smdebug_rulesconfig==1.0.1
#   Downloading smdebug_rulesconfig-1.0.1-py2.py3-none-any.whl (20 kB)
# Collecting importlib-metadata>=1.4.0
#   Downloading importlib_metadata-4.8.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from sagemaker) (20.9)
# Requirement already satisfied: pandas in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from sagemaker) (1.2.4)
# Collecting pathos
#   Downloading pathos-0.2.8-py2.py3-none-any.whl (81 kB)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from boto3>=1.16.32->sagemaker) (0.10.0)
# Requirement already satisfied: botocore<1.22.0,>=1.21.44 in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from boto3>=1.16.32->sagemaker) (1.21.44)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from boto3>=1.16.32->sagemaker) (0.5.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from botocore<1.22.0,>=1.21.44->boto3>=1.16.32->sagemaker) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from botocore<1.22.0,>=1.21.44->boto3>=1.16.32->sagemaker) (1.26.4)
# Collecting zipp>=0.5
#   Downloading zipp-3.5.0-py3-none-any.whl (5.7 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from packaging>=20.0->sagemaker) (2.4.7)
# WARNING: You are using pip version 21.1.2; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\users\admin\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: six>=1.9 in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from protobuf>=3.1->sagemaker) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from pandas->sagemaker) (2021.1)
# Collecting ppft>=1.6.6.4
#   Downloading ppft-1.6.6.4-py3-none-any.whl (65 kB)
# Collecting pox>=0.3.0
#   Downloading pox-0.3.0-py2.py3-none-any.whl (30 kB)
# Collecting dill>=0.3.4
#   Downloading dill-0.3.4-py2.py3-none-any.whl (86 kB)
# Collecting multiprocess>=0.70.12
#   Downloading multiprocess-0.70.12.2-py38-none-any.whl (128 kB)
# Building wheels for collected packages: sagemaker, protobuf3-to-dict
#   Building wheel for sagemaker (setup.py): started
#   Building wheel for sagemaker (setup.py): finished with status 'done'
#   Created wheel for sagemaker: filename=sagemaker-2.59.2-py2.py3-none-any.whl size=618519 sha256=60463e21d87e6f586586d3b03f4ef72997dda02fe4c820a61e989d24ba491041
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\f3\8f\6b\c42fa8658e4de4bb2adc172ae82a9372d37a4f7fd98bdca0b2
#   Building wheel for protobuf3-to-dict (setup.py): started
#   Building wheel for protobuf3-to-dict (setup.py): finished with status 'done'
#   Created wheel for protobuf3-to-dict: filename=protobuf3_to_dict-0.1.5-py3-none-any.whl size=4030 sha256=0e5b99655b87491148db03c792e99d32ce6d7bbe2a94f2d3122f68b00636884f
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\fc\10\27\2d1e23d8b9a9013a83fbb418a0b17b1e6f81c8db8f53b53934
# Successfully built sagemaker protobuf3-to-dict
# Installing collected packages: dill, zipp, ppft, pox, multiprocess, smdebug-rulesconfig, protobuf3-to-dict, pathos, importlib-metadata, sagemaker
# Successfully installed dill-0.3.4 importlib-metadata-4.8.1 multiprocess-0.70.12.2 pathos-0.2.8 pox-0.3.0 ppft-1.6.6.4 protobuf3-to-dict-0.1.5 sagemaker-2.59.2 smdebug-rulesconfig-1.0.1 zipp-3.5.0

# %%
# !pip install mxnet
# Out:
# Collecting mxnet
#   Downloading mxnet-1.7.0.post2-py2.py3-none-win_amd64.whl (33.1 MB)
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting numpy<1.17.0,>=1.8.2
#   Downloading numpy-1.16.6.zip (5.1 MB)
# Collecting requests<2.19.0,>=2.18.4
#   Using cached requests-2.18.4-py2.py3-none-any.whl (88 kB)
# Collecting chardet<3.1.0,>=3.0.2
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting urllib3<1.23,>=1.21.1
#   Using cached urllib3-1.22-py2.py3-none-any.whl (132 kB)
# Collecting idna<2.7,>=2.5
#   Using cached idna-2.6-py2.py3-none-any.whl (56 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (from requests<2.19.0,>=2.18.4->mxnet) (2020.12.5)
# Building wheels for collected packages: numpy
#   Building wheel for numpy (setup.py): started
#   Building wheel for numpy (setup.py): finished with status 'error'
#   Running setup.py clean for numpy
# Failed to build numpy
# Installing collected packages: urllib3, idna, chardet, requests, numpy, graphviz, mxnet
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.4
#     Uninstalling urllib3-1.26.4:
#       Successfully uninstalled urllib3-1.26.4
#   Attempting uninstall: idna
#     Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Uninstalling chardet-4.0.0:
#       Successfully uninstalled chardet-4.0.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#     Running setup.py install for numpy: started
#     Running setup.py install for numpy: finished with status 'error'
#   Rolling back uninstall of numpy
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy-1.19.5.dist-info\
#    from C:\Users\admin\AppData\Local\Programs\Python\Python38\Lib\site-packages\~umpy-1.19.5.dist-info
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\.libs\libopenblas.wcdjnk7yvmpzq2me2zzhjjrj3jikndb7.gfortran-win_amd64.dll
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-mz3m4v9f\libopenblas.wcdjnk7yvmpzq2me2zzhjjrj3jikndb7.gfortran-win_amd64.dll
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\__config__.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\__config__.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\__init__.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\__init__.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\__pycache__\
#    from C:\Users\admin\AppData\Local\Programs\Python\Python38\Lib\site-packages\numpy\~-pycache__
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\_distributor_init.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\_distributor_init.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\_globals.py
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\users\admin\appdata\local\programs\python\python38\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\admin\\AppData\\Local\\Temp\\pip-install-2i7dqa7a\\numpy_6b7fd93039e64ec3a2a57de993fadbf5\\setup.py'"'"'; __file__='"'"'C:\\Users\\admin\\AppData\\Local\\Temp\\pip-install-2i7dqa7a\\numpy_6b7fd93039e64ec3a2a57de993fadbf5\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\admin\AppData\Local\Temp\pip-wheel-kjce7b76'
#        cwd: C:\Users\admin\AppData\Local\Temp\pip-install-2i7dqa7a\numpy_6b7fd93039e64ec3a2a57de993fadbf5\
#   Complete output (264 lines):
#   Running from numpy source directory.
#   C:\Users\admin\AppData\Local\Temp\pip-install-2i7dqa7a\numpy_6b7fd93039e64ec3a2a57de993fadbf5\numpy\distutils\misc_util.py:476: SyntaxWarning: "is" with a literal. Did you mean "=="?
#     return is_string(s) and ('*' in s or '?' is s)
#   blas_opt_info:
#   blas_mkl_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries mkl_rt not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#     NOT AVAILABLE
#
#   blis_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries blis not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#     NOT AVAILABLE
#
#   openblas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#   get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#   customize GnuFCompiler
#   Could not locate executable g77
#   Could not locate executable f77
#   customize IntelVisualFCompiler
#   Could not locate executable ifort
#   Could not locate executable ifl
#   customize AbsoftFCompiler
#   Could not locate executable f90
#   customize CompaqVisualFCompiler
#   Could not locate executable DF
#   customize IntelItaniumVisualFCompiler
#   Could not locate executable efl
#   customize Gnu95FCompiler
#   Could not locate executable gfortran
#   Could not locate executable f95
#   customize G95FCompiler
#   Could not locate executable g95
#   customize IntelEM64VisualFCompiler
#   customize IntelEM64TFCompiler
#   Could not locate executable efort
#   Could not locate executable efc
#   customize PGroupFlangCompiler
#   Could not locate executable flang
#   don't know how to compile Fortran code on platform 'nt'
#     NOT AVAILABLE
#
#   atlas_3_10_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#     NOT AVAILABLE
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\_globals.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\_pytesttester.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\_pytesttester.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\compat\
#    from C:\Users\admin\AppData\Local\Programs\Python\Python38\Lib\site-packages\numpy\~-mpat
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\conftest.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\conftest.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\__init__.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\__init__.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\__pycache__\
#    from C:\Users\admin\AppData\Local\Programs\Python\Python38\Lib\site-packages\numpy\core\~_pycache__
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\_add_newdocs.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\_add_newdocs.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\_asarray.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\_asarray.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\_dtype.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\_dtype.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\_dtype_ctypes.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\_dtype_ctypes.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\_exceptions.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\_exceptions.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\_internal.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\_internal.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\_methods.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\_methods.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\_multiarray_tests.cp38-win_amd64.pyd
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\_multiarray_tests.cp38-win_amd64.pyd
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\_multiarray_umath.cp38-win_amd64.pyd
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\_multiarray_umath.cp38-win_amd64.pyd
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\_operand_flag_tests.cp38-win_amd64.pyd
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\_operand_flag_tests.cp38-win_amd64.pyd
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\_rational_tests.cp38-win_amd64.pyd
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\_rational_tests.cp38-win_amd64.pyd
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\_string_helpers.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\_string_helpers.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\_struct_ufunc_tests.cp38-win_amd64.pyd
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\_struct_ufunc_tests.cp38-win_amd64.pyd
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\_type_aliases.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\_type_aliases.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\_ufunc_config.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\_ufunc_config.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\_umath_tests.cp38-win_amd64.pyd
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\_umath_tests.cp38-win_amd64.pyd
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\arrayprint.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\arrayprint.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\cversions.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\cversions.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\defchararray.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\defchararray.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\einsumfunc.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\einsumfunc.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\fromnumeric.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\fromnumeric.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\function_base.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\function_base.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\generate_numpy_api.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\generate_numpy_api.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\getlimits.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\getlimits.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\include\numpy\
#    from C:\Users\admin\AppData\Local\Programs\Python\Python38\Lib\site-packages\numpy\core\include\~umpy
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\lib\
#    from C:\Users\admin\AppData\Local\Programs\Python\Python38\Lib\site-packages\numpy\core\~ib
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\machar.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\machar.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\memmap.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\memmap.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\multiarray.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\multiarray.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\numeric.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\numeric.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\numerictypes.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\numerictypes.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\overrides.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\overrides.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\records.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\records.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\setup.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\setup.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\setup_common.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\setup_common.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\shape_base.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\shape_base.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__init__.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__init__.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\__init__.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\__init__.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\_locales.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\_locales.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test__exceptions.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test__exceptions.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_abc.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_abc.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_api.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_api.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_arrayprint.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_arrayprint.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_datetime.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_datetime.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_defchararray.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_defchararray.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_deprecations.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_deprecations.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_dtype.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_dtype.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_einsum.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_einsum.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_errstate.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_errstate.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_extint128.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_extint128.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_function_base.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_function_base.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_getlimits.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_getlimits.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_half.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_half.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_indexerrors.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_indexerrors.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_indexing.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_indexing.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_item_selection.cpython-38.pyc
#   atlas_3_10_blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#     NOT AVAILABLE
#
#   atlas_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#     NOT AVAILABLE
#
#   atlas_blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#     NOT AVAILABLE
#
#   accelerate_info:
#     NOT AVAILABLE
#
#   C:\Users\admin\AppData\Local\Temp\pip-install-2i7dqa7a\numpy_6b7fd93039e64ec3a2a57de993fadbf5\numpy\distutils\system_info.py:639: UserWarning:
#       Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [atlas]) or by setting
#       the ATLAS environment variable.
#     self.calc_info()
#   blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries blas not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#     NOT AVAILABLE
#
#   C:\Users\admin\AppData\Local\Temp\pip-install-2i7dqa7a\numpy_6b7fd93039e64ec3a2a57de993fadbf5\numpy\distutils\system_info.py:639: UserWarning:
#       Blas (http://www.netlib.org/blas/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [blas]) or by setting
#       the BLAS environment variable.
#     self.calc_info()
#   blas_src_info:
#     NOT AVAILABLE
#
#   C:\Users\admin\AppData\Local\Temp\pip-install-2i7dqa7a\numpy_6b7fd93039e64ec3a2a57de993fadbf5\numpy\distutils\system_info.py:639: UserWarning:
#       Blas (http://www.netlib.org/blas/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [blas_src]) or by setting
#       the BLAS_SRC environment variable.
#     self.calc_info()
#     NOT AVAILABLE
#
#   'svnversion' is not recognized as an internal or external command,
#   operable program or batch file.
#   non-existing path in 'numpy\\distutils': 'site.cfg'
#   lapack_opt_info:
#   lapack_mkl_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries mkl_rt not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#     NOT AVAILABLE
#
#   openblas_lapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#     NOT AVAILABLE
#
#   openblas_clapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas,lapack not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#     NOT AVAILABLE
#
#   atlas_3_10_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in c:\users\admin\appdata\local\programs\python\python38\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in c:\users\admin\appdata\local\programs\python\python38\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in c:\users\admin\appdata\local\programs\python\python38\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in c:\users\admin\appdata\local\programs\python\python38\libs
#   <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#     NOT AVAILABLE
#
#   atlas_3_10_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in c:\users\admin\appdata\local\programs\python\python38\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in c:\users\admin\appdata\local\programs\python\python38\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in c:\users\admin\appdata\local\programs\python\python38\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in c:\users\admin\appdata\local\programs\python\python38\libs
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_item_selection.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_longdouble.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_longdouble.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_machar.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_machar.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_mem_overlap.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_mem_overlap.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_memmap.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_memmap.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_multiarray.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_multiarray.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_nditer.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_nditer.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_numeric.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_numeric.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_numerictypes.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_numerictypes.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_overrides.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_overrides.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_print.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_print.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_records.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_records.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_regression.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_regression.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_scalar_ctors.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_scalar_ctors.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_scalar_methods.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_scalar_methods.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_scalarbuffer.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_scalarbuffer.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_scalarinherit.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_scalarinherit.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_scalarmath.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_scalarmath.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_scalarprint.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_scalarprint.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_shape_base.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_shape_base.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_ufunc.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_ufunc.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_umath.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_umath.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_umath_accuracy.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_umath_accuracy.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_umath_complex.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_umath_complex.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\__pycache__\test_unicode.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\__pycache__\test_unicode.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\_locales.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\_locales.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\data\
#    from C:\Users\admin\AppData\Local\Programs\Python\Python38\Lib\site-packages\numpy\core\tests\~ata
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test__exceptions.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test__exceptions.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_abc.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_abc.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_api.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_api.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_arrayprint.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_arrayprint.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_datetime.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_datetime.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_defchararray.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_defchararray.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_deprecations.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_deprecations.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_dtype.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_dtype.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_einsum.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_einsum.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_errstate.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_errstate.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_extint128.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_extint128.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_function_base.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_function_base.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_getlimits.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_getlimits.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_half.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_half.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_indexerrors.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_indexerrors.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_indexing.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_indexing.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_item_selection.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_item_selection.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_longdouble.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_longdouble.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_machar.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_machar.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_mem_overlap.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_mem_overlap.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_memmap.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_memmap.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_multiarray.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_multiarray.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_nditer.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_nditer.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_numeric.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_numeric.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_numerictypes.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_numerictypes.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_overrides.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_overrides.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_print.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_print.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_records.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_records.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_regression.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_regression.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_scalar_ctors.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_scalar_ctors.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_scalar_methods.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_scalar_methods.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_scalarbuffer.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_scalarbuffer.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_scalarinherit.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_scalarinherit.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_scalarmath.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_scalarmath.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_scalarprint.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_scalarprint.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_shape_base.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_shape_base.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_ufunc.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_ufunc.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_umath.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_umath.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_umath_accuracy.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_umath_accuracy.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_umath_complex.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_umath_complex.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\tests\test_unicode.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\tests\test_unicode.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\umath.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\umath.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\core\umath_tests.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\core\umath_tests.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\ctypeslib.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\ctypeslib.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\__config__.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\distutils\__config__.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\__init__.py
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\distutils\__init__.py
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\__pycache__\__config__.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\distutils\__pycache__\__config__.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\__pycache__\__init__.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\distutils\__pycache__\__init__.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\__pycache__\_shell_utils.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\distutils\__pycache__\_shell_utils.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\__pycache__\ccompiler.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\distutils\__pycache__\ccompiler.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\__pycache__\conv_template.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\distutils\__pycache__\conv_template.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\__pycache__\core.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\distutils\__pycache__\core.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\__pycache__\cpuinfo.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\distutils\__pycache__\cpuinfo.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\__pycache__\exec_command.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\distutils\__pycache__\exec_command.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\__pycache__\extension.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\distutils\__pycache__\extension.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\__pycache__\from_template.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\distutils\__pycache__\from_template.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\__pycache__\intelccompiler.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\distutils\__pycache__\intelccompiler.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\__pycache__\lib2def.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\distutils\__pycache__\lib2def.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\__pycache__\line_endings.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\distutils\__pycache__\line_endings.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\__pycache__\log.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\distutils\__pycache__\log.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\__pycache__\mingw32ccompiler.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\distutils\__pycache__\mingw32ccompiler.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\__pycache__\misc_util.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\distutils\__pycache__\misc_util.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\__pycache__\msvc9compiler.cpython-38.pyc
#    from C:\Users\admin\AppData\Local\Temp\pip-uninstall-343qihyo\distutils\__pycache__\msvc9compiler.cpython-38.pyc
#   Moving to c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\__pycache__\msvccompiler.cpython-38.pyc
# ...
#     Complete output (267 lines):
#     Running from numpy source directory.
#
#     Note: if you need reliable uninstall behavior, then install
#     with pip instead of using `setup.py install`:
#
#       - `pip install .`       (from a git repo or downloaded source
#                                release)
#       - `pip install numpy`   (last NumPy release on PyPi)
#
#
#     blas_opt_info:
#     blas_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#       NOT AVAILABLE
#
#     blis_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blis not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#       NOT AVAILABLE
#
#     openblas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#     get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#     customize GnuFCompiler
#     Could not locate executable g77
#     Could not locate executable f77
#     customize IntelVisualFCompiler
#     Could not locate executable ifort
#     Could not locate executable ifl
#     customize AbsoftFCompiler
#     Could not locate executable f90
#     customize CompaqVisualFCompiler
#     Could not locate executable DF
#     customize IntelItaniumVisualFCompiler
#     Could not locate executable efl
#     customize Gnu95FCompiler
#     Could not locate executable gfortran
#     Could not locate executable f95
#     customize G95FCompiler
#     Could not locate executable g95
#     customize IntelEM64VisualFCompiler
#     customize IntelEM64TFCompiler
#     Could not locate executable efort
#     Could not locate executable efc
#     customize PGroupFlangCompiler
#     Could not locate executable flang
#     don't know how to compile Fortran code on platform 'nt'
#       NOT AVAILABLE
#
#     atlas_3_10_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#       NOT AVAILABLE
#
#     accelerate_info:
#       NOT AVAILABLE
#
#     C:\Users\admin\AppData\Local\Temp\pip-install-2i7dqa7a\numpy_6b7fd93039e64ec3a2a57de993fadbf5\numpy\distutils\system_info.py:639: UserWarning:
#         Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [atlas]) or by setting
#         the ATLAS environment variable.
#       self.calc_info()
#     blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blas not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#       NOT AVAILABLE
#
#     C:\Users\admin\AppData\Local\Temp\pip-install-2i7dqa7a\numpy_6b7fd93039e64ec3a2a57de993fadbf5\numpy\distutils\system_info.py:639: UserWarning:
#         Blas (http://www.netlib.org/blas/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [blas]) or by setting
#         the BLAS environment variable.
#       self.calc_info()
#     blas_src_info:
#       NOT AVAILABLE
#
#     C:\Users\admin\AppData\Local\Temp\pip-install-2i7dqa7a\numpy_6b7fd93039e64ec3a2a57de993fadbf5\numpy\distutils\system_info.py:639: UserWarning:
#         Blas (http://www.netlib.org/blas/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [blas_src]) or by setting
#         the BLAS_SRC environment variable.
#       self.calc_info()
#       NOT AVAILABLE
#
#     'svnversion' is not recognized as an internal or external command,
#     operable program or batch file.
#     non-existing path in 'numpy\\distutils': 'site.cfg'
#     lapack_opt_info:
#     lapack_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#       NOT AVAILABLE
#
#     openblas_lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#       NOT AVAILABLE
#
#     openblas_clapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas,lapack not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\users\admin\appdata\local\programs\python\python38\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in c:\users\admin\appdata\local\programs\python\python38\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\users\admin\appdata\local\programs\python\python38\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in c:\users\admin\appdata\local\programs\python\python38\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       NOT AVAILABLE
#
#     atlas_3_10_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\users\admin\appdata\local\programs\python\python38\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in c:\users\admin\appdata\local\programs\python\python38\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\users\admin\appdata\local\programs\python\python38\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in c:\users\admin\appdata\local\programs\python\python38\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       NOT AVAILABLE
#
#     atlas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\users\admin\appdata\local\programs\python\python38\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in c:\users\admin\appdata\local\programs\python\python38\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\users\admin\appdata\local\programs\python\python38\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in c:\users\admin\appdata\local\programs\python\python38\libs
#     <class 'numpy.distutils.system_info.atlas_threads_info'>
#       NOT AVAILABLE
#
#     atlas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\users\admin\appdata\local\programs\python\python38\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in c:\users\admin\appdata\local\programs\python\python38\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\users\admin\appdata\local\programs\python\python38\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in c:\users\admin\appdata\local\programs\python\python38\libs
#     <class 'numpy.distutils.system_info.atlas_info'>
#       NOT AVAILABLE
#
#     lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack not found in ['c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\admin\\appdata\\local\\programs\\python\\python38\\libs']
#       NOT AVAILABLE
#
#     C:\Users\admin\AppData\Local\Temp\pip-install-2i7dqa7a\numpy_6b7fd93039e64ec3a2a57de993fadbf5\numpy\distutils\system_info.py:639: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [lapack]) or by setting
#         the LAPACK environment variable.
#       self.calc_info()
#     lapack_src_info:
#       NOT AVAILABLE
#
#     C:\Users\admin\AppData\Local\Temp\pip-install-2i7dqa7a\numpy_6b7fd93039e64ec3a2a57de993fadbf5\numpy\distutils\system_info.py:639: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#         the LAPACK_SRC environment variable.
#       self.calc_info()
#       NOT AVAILABLE
#
#     c:\users\admin\appdata\local\programs\python\python38\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'define_macros'
#       warnings.warn(msg)
#     running install
#     running build
#     running config_cc
#     unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#     running config_fc
#     unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#     running build_src
#     build_src
#     building py_modules sources
#     building library "npymath" sources
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     error: Microsoft Visual C++ 14.0 is required. Get it with "Microsoft Visual C++ Build Tools": https://visualstudio.microsoft.com/downloads/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'c:\users\admin\appdata\local\programs\python\python38\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\admin\\AppData\\Local\\Temp\\pip-install-2i7dqa7a\\numpy_6b7fd93039e64ec3a2a57de993fadbf5\\setup.py'"'"'; __file__='"'"'C:\\Users\\admin\\AppData\\Local\\Temp\\pip-install-2i7dqa7a\\numpy_6b7fd93039e64ec3a2a57de993fadbf5\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\admin\AppData\Local\Temp\pip-record-5w3lxtza\install-record.txt' --single-version-externally-managed --compile --install-headers 'c:\users\admin\appdata\local\programs\python\python38\Include\numpy' Check the logs for full command output.
# WARNING: You are using pip version 21.1.2; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\users\admin\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
import os
import urllib.request
import boto3, botocore


import sagemaker
from sagemaker import get_execution_role

import mxnet as mx
mxnet_path = mx.__file__[ : mx.__file__.rfind('/')]
print(mxnet_path)

role = get_execution_role()
print(role)

sess = sagemaker.Session()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-902bc1382c59> in <module>
#       7 from sagemaker import get_execution_role
#       8
# ----> 9 import mxnet as mx
#      10 mxnet_path = mx.__file__[ : mx.__file__.rfind('/')]
#      11 print(mxnet_path)
#
# ModuleNotFoundError: No module named 'mxnet'

# %% [markdown]
# ## Amazon S3 bucket info
# Enter your Amazon S3 Bucket name where your data will be stored, make sure that your SageMaker notebook has access to this S3 Bucket by granting `S3FullAccess` in the SageMaker role attached to this instance. See [here](https://docs.aws.amazon.com/sagemaker/latest/dg/gs-config-permissions.html) for more info.
#
# DeepLens-compatible buckets must start with `deeplens`

# %%
BUCKET = 'deeplens-<Your-Test-Bucket>'
PREFIX = 'deeplens-trash-test'

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
training_image = get_image_uri(sess.boto_region_name, 'image-classification', repo_version="latest")
print (training_image)

# %% [markdown]
# We are going to check if we have the right bucket and if we have the right permissions.
#
# Please make sure that the result from this cell is "Bucket access is Ok"

# %%
test_data = 'TestData'
s3 = boto3.resource('s3')
object = s3.Object(BUCKET, PREFIX+"/test.txt")
try:
    object.put(Body=test_data)
except botocore.exceptions.ClientError as e:
    if e.response['Error']['Code'] == "AccessDenied":
        #cannot write on the bucket
        print("Bucket "+BUCKET+"is not writeable, make sure you have the right permissions")
    else:
        if e.response['Error']['Code'] == "NoSuchBucket":
            #Bucket does not exist
            print("Bucket"+BUCKET+" does not exist")
        else:
            raise
else:
    print("Bucket access is Ok")
    object.delete(BUCKET, PREFIX+"/test.txt")

# %% [markdown]
# # Prepare data

# %% [markdown]
# It is assumed that your custom dataset's images are present in an S3 bucket and that different classes are separated by named folders, as shown in the following directory structure:
# ```
# |-deeplens-bucket
#    |-deeplens-trash
#
#     |-images
#
#         |-Compost
#
#         |-Landfill
#
#         |-Recycle
#  ```

# %% [markdown]
# Since we are providing the data for you in this example, first we'll download the example data, unzip it and upload it to your bucket.

# %%
# !wget https://deeplens-public.s3.amazonaws.com/samples/deeplens-trash/trash-images.zip

# %%
# !rm -rf data/ && mkdir -p data
# !mkdir -p data/images
# !unzip -qq trash-images.zip -d data/images
# !rm trash-images.zip

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def show_images(item_name, images_to_show=-1):
    _im_list = !ls $IMAGES_DIR/$item_name

    NUM_COLS = 3
    if images_to_show == -1:
        IM_COUNT = len(_im_list)
    else:
        IM_COUNT = images_to_show
    
    print('Displaying images category ' + item_name + ' count: ' + str(IM_COUNT) + ' images.')
    
    NUM_ROWS = int(IM_COUNT / NUM_COLS)
    if ((IM_COUNT % NUM_COLS) > 0):
        NUM_ROWS += 1

    fig, axarr = plt.subplots(NUM_ROWS, NUM_COLS)
    fig.set_size_inches(10.0, 10.0, forward=True)

    curr_row = 0
    for curr_img in range(IM_COUNT):
        # fetch the url as a file type object, then read the image
        f = IMAGES_DIR + item_name + '/' + _im_list[curr_img]
        a = plt.imread(f)

        # find the column by taking the current index modulo 3
        col = curr_img % NUM_ROWS
        # plot on relevant subplot
        if NUM_ROWS == 1:
            axarr[curr_row].imshow(a)
        else:
            axarr[col, curr_row].imshow(a)
        if col == (NUM_ROWS - 1):
            # we have finished the current row, so increment row counter
            curr_row += 1

    fig.tight_layout()       
    plt.show()
        
    # Clean up
    plt.clf()
    plt.cla()
    plt.close()

# %%
IMAGES_DIR = 'data/images/'
show_images("Compost", images_to_show=3)
show_images("Landfill", images_to_show=3)
show_images("Recycling", images_to_show=3)

# %%
DEST_BUCKET = 's3://'+BUCKET+'/'+PREFIX+'/images/'

# %%
# !aws s3 cp --recursive data/images $DEST_BUCKET --quiet

# %% [markdown]
# Ensure that the newly created directories containing the downloaded data are structured as shown at the beginning of this tutorial.

# %%
# !aws s3 ls $DEST_BUCKET

# %% [markdown]
# #### Prepare "list" files with train-val split
#
# The image classification algorithm can take two types of input formats. The first is a [RecordIO format](https://mxnet.apache.org/api/faq/recordio) (content type: application/x-recordio) and the other is a Image list format (.lst file). These file formats allows for efficient loading of images when training the model. In this example we will be using the Image list format (.lst file). A .lst file is a tab-separated file with three columns that contains a list of image files. The first column specifies the image index, the second column specifies the class label index for the image, and the third column specifies the relative path of the image file. The RecordIO file contains the actual pixel data for the images.
#
# To be able to create the .rec files, we first need to split the data into training and validation sets (after shuffling) and create two list files for each. Here our split into train, validation and test (specified by the `0.7` parameter below for test). We keep 0.02% to test the model.

# %% [markdown]
# The image and lst files will be converted to RecordIO file internally by the image classification algorithm. But if you want do the conversion, the following cell shows how to do it using the [im2rec](https://github.com/apache/incubator-mxnet/blob/master/tools/im2rec.py) tool. Note that this is just an example of creating RecordIO files. We are **_not_** using them for training in this notebook.

# %%
# !python $mxnet_path/tools/im2rec.py --list --recursive --test-ratio=0.02 --train-ratio 0.7 trash data/images

# %% [markdown]
# ## Save lst files to S3
# Training models is easy with Amazon SageMaker. When you’re ready to train in SageMaker, simply specify the location of your data in Amazon S3, and indicate the type and quantity of SageMaker ML instances you need. SageMaker sets up a distributed compute cluster, performs the training, outputs the result to Amazon S3, and tears down the cluster when complete.
# To use Amazon Sagemaker training we must first transfer our input data to Amazon S3.

# %%
s3train_lst = 's3://{}/{}/train_lst/'.format(BUCKET, PREFIX)
s3validation_lst = 's3://{}/{}/validation_lst/'.format(BUCKET, PREFIX)

# upload the lst files to train_lst and validation_lst channels
# !aws s3 cp trash_train.lst $s3train_lst --quiet
# !aws s3 cp trash_val.lst $s3validation_lst --quiet

# %% [markdown]
# #### Retrieve dataset size

# %% [markdown]
# Let's see the size of train, validation and test datasets

# %%
f = open('trash_train.lst', 'r')
train_samples = sum(1 for line in f)
f.close()
f = open('trash_val.lst', 'r')
val_samples = sum(1 for line in f)
f.close()
f = open('trash_test.lst', 'r')
test_samples = sum(1 for line in f)
f.close()
print('train_samples:', train_samples)
print('val_samples:', val_samples)
print('test_samples:', test_samples)

# %% [markdown]
# This marks the end of the data preparation phase.

# %% [markdown]
# # Train the model
#
# Training a good model from scratch can take a long time. Fortunately, we're able to use transfer learning to fine-tune a model that has been trained on millions of images. Transfer learning allows us to train a model to recognize new classes in minutes instead of hours or days that it would normally take to train the model from scratch. Transfer learning requires a lot less data to train a model than from scratch (hundreds instead of tens of thousands).

# %% [markdown]
# ## Fine-tuning the Image Classification Model
# Now that we are done with all the setup that is needed, we are ready to train our trash detector. To begin, let us create a ``sageMaker.estimator.Estimator`` object. This estimator will launch the training job.
# ### Training parameters
# There are two kinds of parameters that need to be set for training. The first one are the parameters for the training job. These include:
#
# * **Training instance count**: This is the number of instances on which to run the training. When the number of instances is greater than one, then the image classification algorithm will run in distributed settings.
# * **Training instance type**: This indicates the type of machine on which to run the training. Typically, we use GPU instances for these training
# * **Output path**: This the s3 folder in which the training output is stored

# %%
s3_output_location = 's3://{}/{}/output'.format(BUCKET, PREFIX)
ic = sagemaker.estimator.Estimator(training_image,
                                         role, 
                                         train_instance_count=1, 
                                         train_instance_type='ml.p2.xlarge',
                                         train_volume_size = 50,
                                         train_max_run = 360000,
                                         input_mode= 'File',
                                         output_path=s3_output_location,
                                         sagemaker_session=sess,
                                         base_job_name='ic-trash')

# %% [markdown]
# Apart from the above set of parameters, there are hyperparameters that are specific to the algorithm. These are:
#
# * **num_layers**: The number of layers (depth) for the network. We use 18 in this samples but other values such as 50, 152 can be used.
# * **use_pretrained_model**: Set to 1 to use pretrained model for transfer learning.
# * **image_shape**: The input image dimensions,'num_channels, height, width', for the network. It should be no larger than the actual image size. The number of channels should be same as the actual image.
# * **num_classes**: This is the number of output classes for the new dataset. For us, we have
# * **num_training_samples**: This is the total number of training samples. It is set to 15240 for caltech dataset with the current split.
# * **mini_batch_size**: The number of training samples used for each mini batch. In distributed training, the number of training samples used per batch will be N * mini_batch_size where N is the number of hosts on which training is run.
# * **epochs**: Number of training epochs.
# * **learning_rate**: Learning rate for training.
# * **top_k**: Report the top-k accuracy during training.
# * **resize**: Resize the image before using it for training. The images are resized so that the shortest side is of this parameter. If the parameter is not set, then the training data is used as such without resizing.
# * **precision_dtype**: Training datatype precision (default: float32). If set to 'float16', the training will be done in mixed_precision mode and will be faster than float32 mode

# %%
ic.set_hyperparameters(num_layers=18,
                             use_pretrained_model=1,
                             image_shape = "3,224,224",
                             num_classes=3,
                             mini_batch_size=128,
                             epochs=10,
                             learning_rate=0.01,
                             top_k=2,
                             num_training_samples=train_samples,
                             resize = 224,
                             precision_dtype='float32')

# %% [markdown]
# ## Input data specification
# Set the data type and channels used for training

# %%
s3images = 's3://{}/{}/images/'.format(BUCKET, PREFIX)

train_data = sagemaker.session.s3_input(s3images, distribution='FullyReplicated', 
                        content_type='application/x-image', s3_data_type='S3Prefix')
validation_data = sagemaker.session.s3_input(s3images, distribution='FullyReplicated', 
                             content_type='application/x-image', s3_data_type='S3Prefix')
train_data_lst = sagemaker.session.s3_input(s3train_lst, distribution='FullyReplicated', 
                        content_type='application/x-image', s3_data_type='S3Prefix')
validation_data_lst = sagemaker.session.s3_input(s3validation_lst, distribution='FullyReplicated', 
                             content_type='application/x-image', s3_data_type='S3Prefix')

data_channels = {'train': train_data, 'validation': validation_data, 
                 'train_lst': train_data_lst, 'validation_lst': validation_data_lst}

# %% [markdown]
# ## Start the training
# Start training by calling the fit method in the estimator

# %%
ic.fit(inputs=data_channels, logs=True)

# %% [markdown]
# #### The output from the above command will have the model accuracy and the time it took to run the training.
# #### You can also view these details by navigating to ``Training -> Training Jobs -> job_name -> View logs`` in the Amazon SageMaker console

# %% [markdown]
# The model trained above can now be found in the `s3://<YOUR_BUCKET>/<PREFIX>/output` path.

# %%
MODEL_PATH = ic.model_data
print(MODEL_PATH)

# %% [markdown]
# ## Deploy to a Sagemaker endpoint
# After training your model is complete, you can test your model by asking it to predict the class of a sample trash image that the model has not seen before. This step is called inference.
#
# Amazon SageMaker provides an HTTPS endpoint where your machine learning model is available to provide inferences. For more information see the [Amazon SageMaker documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/how-it-works-hosting.html).

# %%
ic_infer = ic.deploy(initial_instance_count=1, instance_type='local')

# %% [markdown]
# ## Test the images against the endpoint
# We will use the test images that were kept aside for testing.

# %%
object_categories = ['Compost', 'Landfill', 'Recycling']

# %%
from IPython.display import Image, display
import json
import numpy as np


def test_model():
    preds = []
    acts  = []
    num_errors = 0
    with open('trash_test.lst', 'r') as f:
        for line in f:
            stripped_line = str(line.strip()).split("\t")
            file_path = stripped_line[2]
            category = int(float(stripped_line[1]))
            with open(IMAGES_DIR + stripped_line[2], 'rb') as f:
                payload = f.read()
                payload = bytearray(payload)

                ic_infer.content_type = 'application/x-image'
                result = json.loads(ic_infer.predict(payload))
            # the result will output the probabilities for all classes
            # find the class with maximum probability and print the class index
            index = np.argmax(result)
            act = object_categories[category]
            pred = object_categories[index]
            conf = result[index]
            print("Result: Predicted: {}, Confidence: {:.2f}, Actual: {} ".format(pred, conf, act))
            acts.append(category)
            preds.append(index)
            if (pred != act):
                num_errors += 1
                print('ERROR on image -- Predicted: {}, Confidence: {:.2f}, Actual: {}'.format(pred, conf, act))
            display(Image(filename=IMAGES_DIR + stripped_line[2], width=100, height=100))

    return num_errors, preds, acts
num_errors, preds, acts = test_model()

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import itertools
COLOR = 'green'
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR
def plot_confusion_matrix(cm, classes,
                          class_name_list,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.GnBu):
    plt.figure(figsize=(7,7))
    plt.grid(False)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), 
                                  range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.gca().set_xticklabels(class_name_list)
    plt.gca().set_yticklabels(class_name_list)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

def create_and_plot_confusion_matrix(actual, predicted):
    cnf_matrix = confusion_matrix(actual, np.asarray(predicted),labels=range(len(object_categories)))
    plot_confusion_matrix(cnf_matrix, classes=range(len(object_categories)), class_name_list=object_categories)

# %% [markdown]
# ## Display confusion matrix showing 'true' and 'predicted' labels
#
# A confusion matrix is a table that is often used to describe the performance of a classification model (or "classifier") on a set of test data for which the true values are known. It's a table  with two dimensions ("actual" and "predicted"), and identical sets of "classes" in both dimensions (each combination of dimension and class is a variable in the contingency table). The diagonal values in the table indicate a match between the predicted class and the actual class.
#
# For more details go to [Confusion matrix](https://en.wikipedia.org/wiki/Confusion_matrix) (Wikipedia)

# %%
create_and_plot_confusion_matrix(acts, preds)

# %% [markdown]
# ## Approximate costs

# %% [markdown]
# As of 03/11/2020 and based on the pricing information displayed on the page: https://aws.amazon.com/sagemaker/pricing/, here's the costs you can expect in a 24 hour period:
#
#  - Notebook instance cost **\\$6** Assuming you choose ml.t3.xlarge (\\$0.233/hour) instance. This can vary based on the size of instance you choose.
#  - Training costs **\\$1.05** : Assuming you will run about 10 training runs in a 24 hour period using the sample dataset provided. The notebook uses a p2.xlarge (\\$1.26/hour) instance
#  - Model hosting **\\$6.72** : Assuming you use the ml.m4.xlarge (\\$0.28/hour) instance running for 24 hours.
#
# *NOTE* : To save on costs, stop your notebook instances and delete the model edpoint when not in use

# %% [markdown]
# ## (Optional) Clean-up

# %% [markdown]
# If you're ready to be done with this notebook, please run the cell below. This will remove the hosted endpoint you created and avoid any charges from a stray instance being left on.

# %%
sess.delete_endpoint(ic_infer.endpoint)
print("Completed")

# %% [markdown]
# ## Rename model to deploy to AWS DeepLens
# The MxNet model that is stored in the S3 bucket contains 2 files: the params file and a symbol.json file. To simplify deployment to AWS DeepLens, we'll modify the params file so that you do not need to specify the number of epochs the model was trained for.

# %%
import glob

# %%
# !rm -rf data/$PREFIX/tmp && mkdir -p data/$PREFIX/tmp
# !aws s3 cp $MODEL_PATH data/$PREFIX/tmp
# !tar -xzvf data/$PREFIX/tmp/model.tar.gz -C data/$PREFIX/tmp

# %%
params_file_name = glob.glob('./data/' + PREFIX + '/tmp/*.params')[0]

# %%
# !mv $params_file_name data/$PREFIX/tmp/image-classification-0000.params

# %%
# !tar -cvzf ./model.tar.gz -C data/$PREFIX/tmp ./image-classification-0000.params ./image-classification-symbol.json

# %%
# !aws s3 cp model.tar.gz $MODEL_PATH

# %% [markdown]
# ## Next steps
#
# At this point, you have completed:
# * Training a model with Amazon Sagemaker using transfer learning
#
# Next you'll deploy this model to AWS DeepLens. If you have started this notebook as part of a tutorial, please go back to the next step in the tutorial. If you have found this notebook through other channels, please go to [awsdeeplens.recipes](http://awsdeeplens.recipes) and select the Trash Detector tutorial to continue.
